# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
car_data=pd.read_csv("toyota.csv",  na_values=["??", "???"])

# %%
car_data.dropna(axis=0, inplace=True)

# %%
car_data
# Out:
#       Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500   23  46986   Diesel   90         1          0  2000      3
# 1     13750   23  72937   Diesel   90         1          0  2000      3
# 2     13950   24  41711   Diesel   90         1          0  2000      3
# 3     14950   26  48000   Diesel   90         0          0  2000      3
# 4     13750   30  38500   Diesel   90         0          0  2000      3
# ...     ...  ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   69  20544   Petrol   86         1          0  1300      3
# 1432  10845   72  19000   Petrol   86         0          0  1300      3
# 1433   8500   71  17016   Petrol   86         0          0  1300      3
# 1434   7250   70  16916   Petrol   86         1          0  1300      3
# 1435   6950   76      1   Petrol  110         0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...      ...
# ...

# %% [markdown]
# # Scatter plot

# %%
sns.set(style="darkgrid")
sns.regplot(x=car_data["Age"], y=car_data["Price"])
# Out:
# <Axes: xlabel='Age', ylabel='Price'>

# %%
sns.set(style="darkgrid")
sns.regplot(x=car_data["Age"], y=car_data["Price"], fit_reg=False)
# Out:
# <Axes: xlabel='Age', ylabel='Price'>

# %%
sns.set(style="darkgrid")
sns.regplot(x=car_data["Age"], y=car_data["Price"],marker="*", fit_reg=False)
# Out:
# <Axes: xlabel='Age', ylabel='Price'>

# %%
sns.lmplot(x="Age", y="Price", data=car_data, fit_reg=False, hue="FuelType", legend=True, palette="Set1")

# %% [markdown]
# # Histogram

# %%
sns.displot(car_data["Age"])

# %%
sns.displot(car_data["Age"], kde=True)

# %%
sns.displot(car_data["Age"], bins=5)

# %% [markdown]
# # Bar plot

# %%
sns.countplot(x='FuelType', data=car_data)
# Out:
# <Axes: xlabel='FuelType', ylabel='count'>

# %%
sns.countplot(x="FuelType", data=car_data, hue="Automatic")
# Out:
# <Axes: xlabel='FuelType', ylabel='count'>

# %% [markdown]
# # Box and whiskers plot

# %%
sns.boxplot(y=car_data["Price"])
# Out:
# <Axes: ylabel='Price'>

# %%
sns.boxplot(x=car_data["FuelType"],y=car_data["Price"])
# Out:
# <Axes: xlabel='FuelType', ylabel='Price'>

# %%
sns.boxplot(x=car_data["FuelType"],y=car_data["Price"], hue="Automatic", data=car_data)
# Out:
# <Axes: xlabel='FuelType', ylabel='Price'>

# %%
f, (ax_b, ax_h)=plt.subplots(2, gridspec_kw={"height_ratios":(.15, .85)})

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots with specified height ratios
fig, (ax_b, ax_h) = plt.subplots(2, figsize=(8, 6), gridspec_kw={"height_ratios": (.15, .85)})

# Boxplot on top
sns.boxplot(x=car_data["Price"], ax=ax_b)

# Histogram below (use sns.histplot instead of sns.displot for Axes compatibility)
sns.histplot(car_data["Price"], ax=ax_h, kde=False)

# Improve layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # Pair Wise

# %%
sns.pairplot(car_data, kind="scatter", hue="FuelType")
plt.show()
